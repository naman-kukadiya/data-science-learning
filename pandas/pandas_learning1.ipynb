# %%
import pandas as pd
data=pd.read_excel(r"D:\pr1_DS.xlsx")
data.head()
# Out:
#     Age Gender    Income Eduvcation level Marial Status Employee Status  \
# 0  32.0  Female  45000.0       Bachelor's        Single        Employed
# 1  45.0    Male  65000.0         Master's       Married        Employed
# 2  28.0  Female  35000.0      High School        Single      Unemployed
# 3  52.0    Male  80000.0        Doctorate       Married        Employed
# 4  36.0  Female  55000.0       Bachelor's      Divorced        Employed
#
#      Industry
# 0  Technology
# 1     Finance
# 2         NaN
# 3   Education
# 4  Healthcare

# %%
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               25 non-null     float64
#  1   Gender            26 non-null     object
#  2   Income            25 non-null     float64
#  3   Eduvcation level  30 non-null     object
#  4   Marial Status     25 non-null     str
#  5   Employee Status   25 non-null     str
#  6   Industry          22 non-null     str
# dtypes: float64(2), object(2), str(3)
# memory usage: 1.8+ KB
# None

# %%
print(data.shape)
# Out:
# (30, 7)

# %%
data.columns
# Out:
# Index(['Age', 'Gender ', 'Income', 'Eduvcation level', 'Marial Status',
#        'Employee Status', 'Industry'],
#       dtype='str')

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
plt.figure(figsize=(10,5))
plt.scatter(data['Age'],data['Income'],marker='o')
plt.title("Relationship between age and income")
plt.xlabel("Age")
plt.ylabel("Income")
plt.show()

#correlation between age and income
correlation=data['Age'].corr(data['Income'])
print("Correlation between age and income is:",correlation)
# Out:
# Correlation between age and income is: 0.9788337421498362

# %%
#box ploat
import seaborn as sns
sns.set(style="whitegrid")
plt.Figure(figsize=(10,5))
sns.boxplot(y=data['Income'])
plt.title("Box plot of income")
plt.ylabel("Income")
plt.show()

# %%
plt.Figure(figsize=(10,5))
data.boxplot(column='Income',by='Gender ')
plt.title("Distribution of income by Gender")
plt.xlabel("Gender")
plt.ylabel("Income")
plt.show()
